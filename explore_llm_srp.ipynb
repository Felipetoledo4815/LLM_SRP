# %%
from dataset.llm_srp_dataset import LLMSRPDataset
import random

# %%
llm_srp_dataset = LLMSRPDataset(['nuscenes'], configs={"nuscenes":"nuscenes_mini"})
i_id = random.randint(0, len(llm_srp_dataset) - 1)

# %% [markdown]
# # Plot entities in a 2D plane

# %%
img_path, triplets, bb_triplets = llm_srp_dataset.__getitem__(i_id)
llm_srp_dataset.plot_data_point(i_id)
print(triplets)
# Out:
# [('person', 'between_40m_and_60m', 'ego'), ('person', 'in_front_of', 'ego'), ('car', 'between_25m_and_40m', 'ego'), ('car', 'to_right_of', 'ego'), ('truck', 'within_25m', 'ego'), ('truck', 'to_left_of', 'ego'), ('car', 'between_40m_and_60m', 'ego'), ('car', 'in_front_of', 'ego'), ('person', 'between_40m_and_60m', 'ego'), ('person', 'in_front_of', 'ego'), ('person', 'between_40m_and_60m', 'ego'), ('person', 'in_front_of', 'ego'), ('person', 'between_40m_and_60m', 'ego'), ('person', 'in_front_of', 'ego'), ('person', 'within_25m', 'ego'), ('person', 'to_left_of', 'ego'), ('car', 'between_25m_and_40m', 'ego'), ('car', 'in_front_of', 'ego')]

# %% [markdown]
# # Plot Bounding Boxes

# %%
img_path, triplets, bb_triplets = llm_srp_dataset.__getitem__(i_id)

# %%
triplet_sample = bb_triplets[0]
print(triplet_sample)
llm_srp_dataset.plot_bounding_box(i_id,bbs=[triplet_sample[0]],entity_types=[triplet_sample[1][0][0]])
# Out:
# ('(691, 467, 712, 505)', [('person', 'between_40m_and_60m', 'ego'), ('person', 'in_front_of', 'ego')])
